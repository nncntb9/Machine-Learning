# %% [markdown]
# # This script contains the following:
# ### 1. Importing libraries and data
# ### 2. Scaling
# ### 3. Saving and exporting data

# %% [markdown]
# ## 1. Importing libraries and data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.preprocessing import StandardScaler

# %%
# defining the path
path = r'C:\users\localadmin\Machine Learning\Data Sets'

# %%
path
# Out:
# 'C:\\users\\localadmin\\Machine Learning\\Data Sets'

# %%
#Importing climate data as df
df = pd.read_csv(os.path.join(path, 'Original Data', 'Dataset-weather-prediction-dataset-processed.csv'))

# %%
#adding a row-identifier 'id'
df.reset_index(inplace=True)
df.rename(columns={'index':'id'}, inplace=True)
df.head()
# Out:
#    id      DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0   0  19600101      1                  7               2.1            0.85
# 1   1  19600102      1                  6               2.1            0.84
# 2   2  19600103      1                  8               2.1            0.90
# 3   3  19600104      1                  3               2.1            0.92
# 4   4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  ...  VALENTIA_cloud_cover  VALENTIA_humidity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22950 entries, 0 to 22949
# Columns: 171 entries, id to VALENTIA_temp_max
# dtypes: float64(145), int64(26)
# memory usage: 29.9 MB

# %%
df.dtypes
# Out:
# id                       int64
# DATE                     int64
# MONTH                    int64
# BASEL_cloud_cover        int64
# BASEL_wind_speed       float64
#                         ...
# VALENTIA_snow_depth      int64
# VALENTIA_sunshine      float64
# VALENTIA_temp_mean     float64
# VALENTIA_temp_min      float64
# VALENTIA_temp_max      float64
# Length: 171, dtype: object

# %%
# any missing values?
df.isnull().sum() #no values missing
# Out:
# id                     0
# DATE                   0
# MONTH                  0
# BASEL_cloud_cover      0
# BASEL_wind_speed       0
#                       ..
# VALENTIA_snow_depth    0
# VALENTIA_sunshine      0
# VALENTIA_temp_mean     0
# VALENTIA_temp_min      0
# VALENTIA_temp_max      0
# Length: 171, dtype: int64

# %%
df.shape
# Out:
# (22950, 171)

# %% [markdown]
# ## 2. Scaling the data

# %% [markdown]
# #### Creating a sub set of only numerical columns before scaling

# %%
#columns to exclude in the scaling
columns_to_exclude = ['id','DATE', 'MONTH']

# %%
#excluded_df
excluded_df = df[columns_to_exclude]

# %%
excluded_df.head()
# Out:
#    id      DATE  MONTH
# 0   0  19600101      1
# 1   1  19600102      1
# 2   2  19600103      1
# 3   3  19600104      1
# 4   4  19600105      1

# %%
# Selecting columns to scale by excluding 'columns_to_exclude'
features_to_scale = df.columns[~df.columns.isin(columns_to_exclude)]

# %%
#create scaler object using StandardScaler from sklearn.preprocessing
#StandardScaler assumes data is normally distributed and scales with a distribution
#around 0 and standard deviation of 1. Scaling happens independently with each variable.

scaler = StandardScaler()

# %%
# Fit and transform the features to scale
scaled_features = scaler.fit_transform(df[features_to_scale])

# %%
# Create a new dataframe with the scaled features
scaled_df = pd.DataFrame(scaled_features, columns=features_to_scale)

# %%
#Checking the head for the scaled dataframe 'scaled_df'
scaled_df.head()
# Out:
#    BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  BASEL_pressure  \
# 0           0.660514          -0.02793        0.826097       -0.001949
# 1           0.244897          -0.02793        0.735760       -0.001949
# 2           1.076130          -0.02793        1.277781       -0.001949
# 3          -1.001953          -0.02793        1.458455       -0.001949
# 4           0.244897          -0.02793        1.729466       -0.001949
#
#    BASEL_global_radiation  BASEL_precipitation  BASEL_snow_depth  \
# 0               -1.101066            -0.265148         -0.179228
# 1               -1.058108             1.658760         -0.179228
# 2               -1.251420             0.155707         -0.179228
# 3               -0.821838            -0.445514         -0.179228
# 4               -0.746661            -0.164944         -0.179228
#
#    BASEL_sunshine  BASEL_temp_mean  BASEL_temp_min  ...  VALENTIA_cloud_cover  \
# ...

# %%
#adding back the excluded columns
result_df = pd.concat([df[columns_to_exclude].reset_index(drop=True), scaled_df.reset_index(drop=True)], axis=1)

# %%
#Checking the head of the re-constituted dataframe after scaling
result_df.head()
# Out:
#    id      DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0   0  19600101      1           0.660514          -0.02793        0.826097
# 1   1  19600102      1           0.244897          -0.02793        0.735760
# 2   2  19600103      1           1.076130          -0.02793        1.277781
# 3   3  19600104      1          -1.001953          -0.02793        1.458455
# 4   4  19600105      1           0.244897          -0.02793        1.729466
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0       -0.001949               -1.101066            -0.265148
# 1       -0.001949               -1.058108             1.658760
# 2       -0.001949               -1.251420             0.155707
# 3       -0.001949               -0.821838            -0.445514
# 4       -0.001949               -0.746661            -0.164944
#
#    BASEL_snow_depth  ...  VALENTIA_cloud_cover  VALENTIA_humidity  \
# ...

# %% [markdown]
# ## 3. Export scaled dataframe as .pkl

# %%
#export the scaled data in pickle form as [DATASET]_scaled
result_df.to_csv(os.path.join(path, 'Processed Data', '[DATASET]_scaled.csv'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 #export the scaled data in pickle form as [DATASET]_scaled
# ----> 2 result_df.to_csv(os.path.join(path, 'Processed Data', '[DATASET]_scaled.csv'))
#
# NameError: name 'result_df' is not defined
